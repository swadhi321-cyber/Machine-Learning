# %%
import pickle

# %%
import pandas as pd

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
indep=dataset[['R&D Spend','Administration', 'Marketing Spend','State_Florida', 'State_New York']]
dep=dataset[['Profit']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train= sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
preinput=sc.transform([[1300,12000,4000,0,1]])
# Out:
# C:\Users\swadh\anaconda4\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.41240431, -4.30496048, -1.44694752, -0.42257713,  1.24034735]])

# %%
loaded_model=pickle.load(open("final_model.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([80062.53852652])
