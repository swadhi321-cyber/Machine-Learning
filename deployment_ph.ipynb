# %%
#deployment phase to check the outcome
import pickle

# %%
loaded_model=pickle.load(open("finalized_decision_tree.sav", 'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])

# %%
result
# Out:
# array([188405.6115])
